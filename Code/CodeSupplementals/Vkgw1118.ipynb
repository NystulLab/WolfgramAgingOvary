# %% [markdown]
# Set-up

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
from statannotations.Annotator import Annotator

# %%
os.getcwd()
#working directory should be /Code/CodeFigure1
# Out:
# '/Users/emilly/Library/CloudStorage/Dropbox/UCSF Nystul Lab/NystulLabRepo/WolfgramAgingOvary/Code/CodeSupplementals'

# %% [markdown]
# Plotting Vkg Intensity in 1 vs 6 week w1118(x)
#
# Note: You will need to run the StatsVkgw1118.Rmd file first, or annotate out the stats code

# %%
csv_path = "../../Data/DataSupplementals/w1118Vkg_n.csv"
df = pd.read_csv(csv_path)

# %%
df['Weeks'] = df['Weeks'].map({1: '1 Week', 6: '6 Weeks'})

df.head(6)
# Out:
#      Weeks  VkgIntensity  n  N
# 0   1 Week      509.6219  8  1
# 1   1 Week      273.1640  9  2
# 2   1 Week      467.3860  9  3
# 3  6 Weeks      191.6020  9  1
# 4  6 Weeks       67.2060  9  2
# 5  6 Weeks      466.6670  9  3

# %%
stats_path = "../../Results/ResultsSupplementals/StatsVkgTtest.csv"
stats = pd.read_csv(stats_path)

stats["WeekNum"] = stats["comparison"].str.extract(r"(\d+)").astype(int)

star = stats.loc[0, "stars"]
week_to_annotate = stats.loc[0, "WeekNum"]

df["WeekNum"] = df["Weeks"].str.extract(r"(\d+)").astype(int)

week_order = sorted(df["WeekNum"].unique())
label_order = (
    df.drop_duplicates("WeekNum")
      .sort_values("WeekNum")["Weeks"]
      .tolist()
)

fig, ax = plt.subplots(figsize=(3, 5))
sns.set(style="white")

barplot = sns.barplot(
    data=df,
    x="Weeks",
    y="VkgIntensity",
    order=label_order,
    palette="gray",
    capsize=0.1,
    err_kws={"color": "black", "linewidth": 3},
    edgecolor="black",
    linewidth=3,
    width=0.7,
    ax=ax
)

sns.stripplot(
    data=df,
    x="Weeks",
    y="VkgIntensity",
    order=label_order,
    color="black",
    alpha=0.5,
    size=6,
    jitter=True,
    ax=ax
)

y_max = df.groupby("WeekNum")["VkgIntensity"].max()
offset = 30

x_position = week_order.index(week_to_annotate)

ax.text(
    x=x_position,
    y=y_max.loc[week_to_annotate] + offset,
    s=star,
    ha="center",
    va="bottom",
    fontsize=30,
    fontweight="bold"
)

plt.ylim(0, 550)
plt.ylabel("Mean Intensity (AU)", fontsize=15, weight="bold")
plt.xlabel("")

ax.tick_params(width=3, labelsize=12)
ax.spines["left"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

results_directory = '../../Results'
filename = os.path.join(results_directory, 'ResultsSupplementals', 'Vkgw1118.pdf')
os.makedirs(os.path.dirname(filename), exist_ok=True)
plt.savefig(
    filename,
    format='pdf',
    bbox_inches='tight'
)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/nx/qkkxq7n92pg6rvbn9x9t9lrr0000px/T/ipykernel_65683/3279062491.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(
